# %%
# !KRB5CCNAME=FILE:/tmp/$JPY_USER_UID/krb5cc_$JPY_USER_UID hdfs dfs -ls /data/fraude_cicos/output
# Out:
# Found 401 items
# drwxr-xr-x   - stratio supergroup          0 2018-12-28 20:51 /data/fraude_cicos/output/for2sav
# drwxr-xr-x   - stratio supergroup          0 2018-12-28 20:52 /data/fraude_cicos/output/for2savtas
# drwxrwxrwx   - stratio supergroup          0 2018-10-11 13:27 /data/fraude_cicos/output/for2savtas.csv
# drwxrwxrwx   - stratio supergroup          0 2018-10-11 13:27 /data/fraude_cicos/output/for2savtas_pruebas
# drwxr-xr-x   - hdfs    supergroup          0 2018-10-18 09:42 /data/fraude_cicos/output/for2savtas_test
# drwxr-xr-x   - stratio supergroup          0 2018-12-28 07:01 /data/fraude_cicos/output/for2savtashis
# drwxrwxrwx   - stratio supergroup          0 2018-10-30 15:41 /data/fraude_cicos/output/for2savtashis_bck
# drwxr-xr-x   - stratio supergroup          0 2018-11-06 12:51 /data/fraude_cicos/output/for2savtashis_sim
# drwxrwxrwx   - hdfs    supergroup          0 2018-07-17 10:53 /data/fraude_cicos/output/prueba_scofra.csv
# ...

# %%
# !KRB5CCNAME=FILE:/tmp/$JPY_USER_UID/krb5cc_$JPY_USER_UID hdfs dfs -ls /data/cicos/nba/output
# Out:
# Found 171 items
# drwxr-xr-x   - stratio supergroup          0 2019-01-03 07:53 /data/cicos/nba/output/for2sav
# -rw-r--r--   3 hdfs    supergroup       4572 2018-10-10 15:39 /data/cicos/nba/output/for2sav_20181010.csv
# drwxr-xr-x   - hdfs    supergroup          0 2018-10-16 12:51 /data/cicos/nba/output/for2sav_test
# drwxr-xr-x   - stratio supergroup          0 2019-01-03 07:03 /data/cicos/nba/output/for2savhis
# drwxr-xr-x   - hdfs    supergroup          0 2018-11-22 18:44 /data/cicos/nba/output/for2savhis_INT
# drwxr-xr-x   - stratio supergroup          0 2018-11-06 16:39 /data/cicos/nba/output/for2savhis_sim
# -rw-r--r--   3 hdfs    supergroup     395973 2018-09-21 08:07 /data/cicos/nba/output/scocic_20180921.csv
# -rw-r--r--   3 hdfs    supergroup     382406 2018-09-24 07:28 /data/cicos/nba/output/scocic_20180924.csv
# -rw-r--r--   3 hdfs    supergroup     378330 2018-09-25 07:07 /data/cicos/nba/output/scocic_20180925.csv
# ...

# %%
# !KRB5CCNAME=FILE:/tmp/$JPY_USER_UID/krb5cc_$JPY_USER_UID hdfs dfs -ls /data/cicos/atribuidos/output/contactabilidad/
# Out:
# Found 23 items
# drwxr-xr-x   - stratio supergroup          0 2018-12-10 18:44 /data/cicos/atribuidos/output/contactabilidad/key=20181210
# drwxr-xr-x   - stratio supergroup          0 2018-12-13 17:49 /data/cicos/atribuidos/output/contactabilidad/key=20181213
# drwxr-xr-x   - stratio supergroup          0 2018-12-14 11:14 /data/cicos/atribuidos/output/contactabilidad/key=20181214
# drwxr-xr-x   - stratio supergroup          0 2018-12-15 05:50 /data/cicos/atribuidos/output/contactabilidad/key=20181215
# drwxr-xr-x   - stratio supergroup          0 2018-12-16 05:44 /data/cicos/atribuidos/output/contactabilidad/key=20181216
# drwxr-xr-x   - stratio supergroup          0 2018-12-17 10:37 /data/cicos/atribuidos/output/contactabilidad/key=20181217
# drwxr-xr-x   - stratio supergroup          0 2018-12-18 13:09 /data/cicos/atribuidos/output/contactabilidad/key=20181218
# ...
